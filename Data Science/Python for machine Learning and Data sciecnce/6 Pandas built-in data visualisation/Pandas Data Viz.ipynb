# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('df1', index_col = 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2', )

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()

# %%
df2.plot.area(alpha = 0.4)

# %%
# bar plots 
df1.plot.bar()

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked = True)

# %%
df1['A'].plot.hist(bins= 50)

# %%
df1.plot.line( y ='B',figsize = (12,3),lw = 1) # we need to specifiy x and y values

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'coolwarm') # scetter will take only x and y values
# if we pass in 3rd value the graph will be in 3 dimension and

# %%
#if we want to show the plot by size rather than color, we need to pass in the column number 
df1.plot.scatter(x = 'A',y ="B", s = df1["C"]*100)
# Out:
# C:\Users\Sandeep Tukkunor\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns = ['a', 'b'])

# %%
df.head()
# Out:
#           a         b
# 0 -0.589168 -1.153655
# 1 -0.490323 -1.342063
# 2  0.634175 -0.770367
# 3  0.456537 -1.052040
# 4  1.806696 -0.192881

# %%
df.plot.hexbin(x= 'a', y = 'b',gridsize = 25, cmap = 'coolwarm')

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()
