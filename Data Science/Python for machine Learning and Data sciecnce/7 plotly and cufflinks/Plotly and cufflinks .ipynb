# %%
#install both of them using pip as they are not available in conda
#plotly is interactive visualization library 
#cufflinks connects between pandas and plotly

# %%
import pandas as pd
import numpy as np
from plotly import __version__
import matplotlib.pyplot as plt

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected= True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# data 
df = pd.DataFrame(np.random.randn(100,4), columns = ['a','b','c','d'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0 -1.982652  1.294552  0.813715  2.004283
# 1 -0.572655  0.008343 -0.044913 -0.519621
# 2  0.062455 -1.084652 -0.436511 -0.197967
# 3  0.248932  0.164132 -0.920818 -1.859188
# 4  0.042774 -0.128282  0.736533 -1.032723

# %%
df2 = pd.DataFrame({"catagory": ['a','b','c'], 'values' : [23,49,12] })

# %%
df2
# Out:
#   catagory  values
# 0        a      23
# 1        b      49
# 2        c      12

# %%
df.plot()

# %%
# just change plot to iplot 
# the output we get, has been converted to plotly interactive image 
df.iplot()
# Out:
# <div>
#
#
#             <div id="e98818c1-7f52-432e-93a4-d1330043eac6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e98818c1-7f52-432e-93a4-d1330043eac6")) {
#                     Plotly.newPlot(
#                         'e98818c1-7f52-432e-93a4-d1330043eac6',
# ...

# %%
df.iplot(kind = 'scatter',x = 'a',y = 'b', mode = 'markers')
# Out:
# <div>
#
#
#             <div id="bdd57a0c-ff11-4381-9efc-b33802af389d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bdd57a0c-ff11-4381-9efc-b33802af389d")) {
#                     Plotly.newPlot(
#                         'bdd57a0c-ff11-4381-9efc-b33802af389d',
# ...

# %%
df2.iplot(kind = 'bar', x = 'catagory', y = 'values')
# Out:
# <div>
#
#
#             <div id="355acd8a-c094-4ce5-8f5e-8ee650fae142" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("355acd8a-c094-4ce5-8f5e-8ee650fae142")) {
#                     Plotly.newPlot(
#                         '355acd8a-c094-4ce5-8f5e-8ee650fae142',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "values", "orientation": "v", "text": "", "type": "bar", "uid": "28aab4ed-380f-4589-ae2d-ab586c9b6517", "x": ["a", "b", "c"], "y": [23, 49, 12]}],
# ...

# %%
df.head()
# Out:
#           a         b         c         d
# 0 -1.982652  1.294552  0.813715  2.004283
# 1 -0.572655  0.008343 -0.044913 -0.519621
# 2  0.062455 -1.084652 -0.436511 -0.197967
# 3  0.248932  0.164132 -0.920818 -1.859188
# 4  0.042774 -0.128282  0.736533 -1.032723

# %%
df.sum().iplot(kind = 'bar' ) #adds the sum of each colums
# Out:
# <div>
#
#
#             <div id="858b7ff2-cac3-49d6-84bc-c4782a091682" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("858b7ff2-cac3-49d6-84bc-c4782a091682")) {
#                     Plotly.newPlot(
#                         '858b7ff2-cac3-49d6-84bc-c4782a091682',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "3608608c-1d35-4ee5-869e-1438e3c2cd01", "x": ["a", "b", "c", "d"], "y": [10.638158550533067, 10.975147785233139, 6.661619851388604, 10.824389912813714]}],
# ...

# %%
#boxplot using iplot
df.iplot(kind = 'box')
# Out:
# <div>
#
#
#             <div id="4dd8ba3c-d11d-4a43-81dd-199ef6a40fd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4dd8ba3c-d11d-4a43-81dd-199ef6a40fd7")) {
#                     Plotly.newPlot(
#                         '4dd8ba3c-d11d-4a43-81dd-199ef6a40fd7',
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z': [5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
#surface plot 
df3.iplot(kind = 'surface', colorscale = 'rdylbu')
# we can also change the colorscale
#check plotly for further referece 
#matplotlib color maping are different from plotly
# Out:
# <div>
#
#
#             <div id="64b31908-1fbd-4e8c-b2c6-adf99515565c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("64b31908-1fbd-4e8c-b2c6-adf99515565c")) {
#                     Plotly.newPlot(
#                         '64b31908-1fbd-4e8c-b2c6-adf99515565c',
# ...

# %%
df.iplot(kind = 'hist') # we will get the dataframe with all the colomn values overlaping
# Out:
# <div>
#
#
#             <div id="12acdb4c-7084-4e34-b370-f5eb13109afd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("12acdb4c-7084-4e34-b370-f5eb13109afd")) {
#                     Plotly.newPlot(
#                         '12acdb4c-7084-4e34-b370-f5eb13109afd',
# ...

# %%
df[['a','b']].iplot(kind = 'spread')
# Out:
# <div>
#
#
#             <div id="9ed5ca26-02ec-4ceb-a7c8-420b141168e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9ed5ca26-02ec-4ceb-a7c8-420b141168e0")) {
#                     Plotly.newPlot(
#                         '9ed5ca26-02ec-4ceb-a7c8-420b141168e0',
# ...

# %%
df.iplot(kind = 'bubble', x = 'a',y = 'b',size = 'c')
# Out:
# <div>
#
#
#             <div id="6b8d66c1-60b8-42b3-9a21-953c5dfcdea5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6b8d66c1-60b8-42b3-9a21-953c5dfcdea5")) {
#                     Plotly.newPlot(
#                         '6b8d66c1-60b8-42b3-9a21-953c5dfcdea5',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="fcb6dca5-cabf-4d88-8fc2-544788d15180" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fcb6dca5-cabf-4d88-8fc2-544788d15180")) {
#                     Plotly.newPlot(
#                         'fcb6dca5-cabf-4d88-8fc2-544788d15180',
# ...
